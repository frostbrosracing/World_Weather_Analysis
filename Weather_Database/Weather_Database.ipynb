# %% [markdown]
# ### Import the dependencies, libraries, modules, and the weather_api_key

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Add the requests library from Anaconda
import requests
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key

# %% [markdown]
# ### Create a set of 2,000 random latitudes and longitudes

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### Get the nearest city using the citypy module

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %% [markdown]
# ### Perform an API call with the OpenWeatherMap

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1113308864fb7c97390b51d68b7ee217

# %% [markdown]
# ### Retrieve the following information from the API call: Latitude and Longitude, Maximum temperature, Percent humidity, Percent cloudiness, Wind speed, Weather description

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | constitucion
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | gusinoye ozero
# Processing Record 4 of Set 1 | sisimiut
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | camacha
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | beringovskiy
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | esna
# Processing Record 13 of Set 1 | lagoa
# Processing Record 14 of Set 1 | tiksi
# Processing Record 15 of Set 1 | carballo
# Processing Record 16 of Set 1 | waitati
# Processing Record 17 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 1 | acapulco
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | palmer
# Processing Record 21 of Set 1 | kangaatsiaq
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | kenai
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 1 | borova
# Processing Record 28 of Set 1 | baherden
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | pocoes
# Processing Record 31 of Set 1 | camopi
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | kpandae
# Processing Record 34 of Set 1 | jalu
# Processing Record 35 of Set 1 | kondratovo
# Processing Record 36 of Set 1 | camargo
# Processing Record 37 of Set 1 | moose factory
# Processing Record 38 of Set 1 | sargatskoye
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | merauke
# Processing Record 41 of Set 1 | bjornevatn
# Processing Record 42 of Set 1 | ornskoldsvik
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | ribeira grande
# Processing Record 45 of Set 1 | voh
# Processing Record 46 of Set 1 | talnakh
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | gorontalo
# Processing Record 49 of Set 1 | paamiut
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | antofagasta
# Processing Record 2 of Set 2 | san patricio
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | high level
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | creel
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | samarai
# Processing Record 9 of Set 2 | cintalapa
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | pirgos
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | faya
# Processing Record 14 of Set 2 | bucerias
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | ormara
# Processing Record 17 of Set 2 | kariba
# Processing Record 18 of Set 2 | luba
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | avera
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | oda
# Processing Record 26 of Set 2 | marawi
# Processing Record 27 of Set 2 | dipkarpaz
# City not found. Skipping...
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | koshurnikovo
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | souillac
# Processing Record 33 of Set 2 | wukari
# Processing Record 34 of Set 2 | berbera
# Processing Record 35 of Set 2 | kapaa
# Processing Record 36 of Set 2 | gbarnga
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | ariquemes
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | asayita
# City not found. Skipping...
# Processing Record 41 of Set 2 | husavik
# Processing Record 42 of Set 2 | bitung
# Processing Record 43 of Set 2 | mikkeli
# Processing Record 44 of Set 2 | matias romero
# Processing Record 45 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 2 | bila tserkva
# Processing Record 47 of Set 2 | jibuti
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | vallenar
# Processing Record 50 of Set 2 | achisay
# City not found. Skipping...
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | vaini
# Processing Record 3 of Set 3 | srednekolymsk
# Processing Record 4 of Set 3 | nanortalik
# Processing Record 5 of Set 3 | saldanha
# Processing Record 6 of Set 3 | coulihaut
# City not found. Skipping...
# Processing Record 7 of Set 3 | feijo
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | geraldton
# Processing Record 10 of Set 3 | hithadhoo
# Processing Record 11 of Set 3 | faanui
# Processing Record 12 of Set 3 | yabelo
# Processing Record 13 of Set 3 | ganganagar
# Processing Record 14 of Set 3 | kaabong
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | okha
# Processing Record 17 of Set 3 | taywarah
# Processing Record 18 of Set 3 | ishigaki
# Processing Record 19 of Set 3 | luanda
# Processing Record 20 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 3 | kayerkan
# Processing Record 23 of Set 3 | eregli
# Processing Record 24 of Set 3 | luderitz
# Processing Record 25 of Set 3 | hilo
# Processing Record 26 of Set 3 | ponta do sol
# Processing Record 27 of Set 3 | te anau
# Processing Record 28 of Set 3 | klaksvik
# Processing Record 29 of Set 3 | labrea
# Processing Record 30 of Set 3 | shelabolikha
# Processing Record 31 of Set 3 | mount gambier
# Processing Record 32 of Set 3 | yakeshi
# Processing Record 33 of Set 3 | coihaique
# Processing Record 34 of Set 3 | portales
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | katsuura
# Processing Record 37 of Set 3 | yerbogachen
# Processing Record 38 of Set 3 | prince albert
# Processing Record 39 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 3 | liverpool
# Processing Record 41 of Set 3 | severo-kurilsk
# Processing Record 42 of Set 3 | thoen
# Processing Record 43 of Set 3 | durango
# Processing Record 44 of Set 3 | maniitsoq
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | makubetsu
# Processing Record 47 of Set 3 | nikolskoye
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | bulgan
# Processing Record 50 of Set 3 | cabedelo
# Processing Record 1 of Set 4 | jiaohe
# Processing Record 2 of Set 4 | mehamn
# Processing Record 3 of Set 4 | laguna
# Processing Record 4 of Set 4 | qobustan
# Processing Record 5 of Set 4 | clyde river
# Processing Record 6 of Set 4 | sinnamary
# Processing Record 7 of Set 4 | pogranichnyy
# Processing Record 8 of Set 4 | alice springs
# Processing Record 9 of Set 4 | grand-santi
# Processing Record 10 of Set 4 | half moon bay
# Processing Record 11 of Set 4 | gwadar
# Processing Record 12 of Set 4 | bambous virieux
# Processing Record 13 of Set 4 | hohhot
# Processing Record 14 of Set 4 | norman wells
# Processing Record 15 of Set 4 | yefira
# City not found. Skipping...
# Processing Record 16 of Set 4 | stornoway
# Processing Record 17 of Set 4 | gorodishche
# Processing Record 18 of Set 4 | torbay
# Processing Record 19 of Set 4 | lekoni
# Processing Record 20 of Set 4 | urusha
# Processing Record 21 of Set 4 | kysyl-syr
# Processing Record 22 of Set 4 | pangnirtung
# Processing Record 23 of Set 4 | shelui
# Processing Record 24 of Set 4 | atkarsk
# Processing Record 25 of Set 4 | zolotyy potik
# Processing Record 26 of Set 4 | udachnyy
# Processing Record 27 of Set 4 | grand island
# Processing Record 28 of Set 4 | yanji
# Processing Record 29 of Set 4 | rodeo
# Processing Record 30 of Set 4 | la ferte-bernard
# Processing Record 31 of Set 4 | havelock
# Processing Record 32 of Set 4 | marzuq
# Processing Record 33 of Set 4 | tianpeng
# Processing Record 34 of Set 4 | conil
# Processing Record 35 of Set 4 | mohacs
# Processing Record 36 of Set 4 | ellisras
# Processing Record 37 of Set 4 | monteagudo
# Processing Record 38 of Set 4 | deniliquin
# Processing Record 39 of Set 4 | cayenne
# Processing Record 40 of Set 4 | teneguiban
# City not found. Skipping...
# Processing Record 41 of Set 4 | georgetown
# Processing Record 42 of Set 4 | cah ab
# City not found. Skipping...
# Processing Record 43 of Set 4 | fairbanks
# Processing Record 44 of Set 4 | dianopolis
# City not found. Skipping...
# Processing Record 45 of Set 4 | shingu
# Processing Record 46 of Set 4 | cherskiy
# Processing Record 47 of Set 4 | bengkulu
# Processing Record 48 of Set 4 | andenes
# Processing Record 49 of Set 4 | tucano
# Processing Record 50 of Set 4 | aizkraukle
# Processing Record 1 of Set 5 | pahrump
# Processing Record 2 of Set 5 | itoman
# Processing Record 3 of Set 5 | kasungu
# Processing Record 4 of Set 5 | iskateley
# Processing Record 5 of Set 5 | burica
# City not found. Skipping...
# Processing Record 6 of Set 5 | chernomorskiy
# Processing Record 7 of Set 5 | hualmay
# Processing Record 8 of Set 5 | namibe
# Processing Record 9 of Set 5 | dzierzoniow
# Processing Record 10 of Set 5 | amapa
# Processing Record 11 of Set 5 | nuuk
# Processing Record 12 of Set 5 | sao miguel do araguaia
# Processing Record 13 of Set 5 | lata
# Processing Record 14 of Set 5 | laiyang
# Processing Record 15 of Set 5 | hasaki
# Processing Record 16 of Set 5 | sigli
# Processing Record 17 of Set 5 | rovaniemi
# Processing Record 18 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 19 of Set 5 | manokwari
# Processing Record 20 of Set 5 | vao
# Processing Record 21 of Set 5 | bukachacha
# Processing Record 22 of Set 5 | viedma
# Processing Record 23 of Set 5 | sao filipe
# Processing Record 24 of Set 5 | santiago de chuco
# Processing Record 25 of Set 5 | garissa
# Processing Record 26 of Set 5 | oranjemund
# Processing Record 27 of Set 5 | tocopilla
# Processing Record 28 of Set 5 | upernavik
# Processing Record 29 of Set 5 | christchurch
# Processing Record 30 of Set 5 | plettenberg bay
# Processing Record 31 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 5 | turukhansk
# Processing Record 33 of Set 5 | cidreira
# Processing Record 34 of Set 5 | saint anthony
# Processing Record 35 of Set 5 | plymouth
# Processing Record 36 of Set 5 | pritzwalk
# Processing Record 37 of Set 5 | jutai
# Processing Record 38 of Set 5 | kieta
# Processing Record 39 of Set 5 | saskylakh
# Processing Record 40 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 5 | kortkeros
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 5 | vigrestad
# Processing Record 47 of Set 5 | ancud
# Processing Record 48 of Set 5 | kristiansund
# Processing Record 49 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 5 | lindsay
# Processing Record 1 of Set 6 | provideniya
# Processing Record 2 of Set 6 | pangody
# Processing Record 3 of Set 6 | sorong
# Processing Record 4 of Set 6 | kampar
# Processing Record 5 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 6 | vila franca do campo
# Processing Record 7 of Set 6 | sitka
# Processing Record 8 of Set 6 | ahipara
# Processing Record 9 of Set 6 | shimoda
# Processing Record 10 of Set 6 | san luis
# Processing Record 11 of Set 6 | robe
# Processing Record 12 of Set 6 | roald
# Processing Record 13 of Set 6 | saint-pierre
# Processing Record 14 of Set 6 | bonaventure
# Processing Record 15 of Set 6 | konstantinovka
# Processing Record 16 of Set 6 | monrovia
# Processing Record 17 of Set 6 | komsomolskiy
# Processing Record 18 of Set 6 | luganville
# Processing Record 19 of Set 6 | serzhen-yurt
# Processing Record 20 of Set 6 | totma
# Processing Record 21 of Set 6 | lethem
# Processing Record 22 of Set 6 | taupo
# Processing Record 23 of Set 6 | vilkaviskis
# Processing Record 24 of Set 6 | lavrentiya
# Processing Record 25 of Set 6 | iqaluit
# Processing Record 26 of Set 6 | galich
# Processing Record 27 of Set 6 | abilene
# Processing Record 28 of Set 6 | mahebourg
# Processing Record 29 of Set 6 | longyearbyen
# Processing Record 30 of Set 6 | ambon
# Processing Record 31 of Set 6 | talcahuano
# Processing Record 32 of Set 6 | mul
# Processing Record 33 of Set 6 | poum
# Processing Record 34 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 6 | mimongo
# Processing Record 36 of Set 6 | bloomfield
# Processing Record 37 of Set 6 | la cruz
# Processing Record 38 of Set 6 | ternate
# Processing Record 39 of Set 6 | tsiroanomandidy
# Processing Record 40 of Set 6 | solvychegodsk
# Processing Record 41 of Set 6 | micomeseng
# Processing Record 42 of Set 6 | carnarvon
# Processing Record 43 of Set 6 | filadelfia
# Processing Record 44 of Set 6 | praxedis guerrero
# Processing Record 45 of Set 6 | kodinsk
# Processing Record 46 of Set 6 | tual
# Processing Record 47 of Set 6 | acarau
# Processing Record 48 of Set 6 | touros
# Processing Record 49 of Set 6 | aswan
# Processing Record 50 of Set 6 | kutum
# Processing Record 1 of Set 7 | wasilla
# Processing Record 2 of Set 7 | spirit river
# Processing Record 3 of Set 7 | sechura
# Processing Record 4 of Set 7 | alofi
# Processing Record 5 of Set 7 | edd
# Processing Record 6 of Set 7 | pakala
# Processing Record 7 of Set 7 | bethel
# Processing Record 8 of Set 7 | alta floresta
# Processing Record 9 of Set 7 | ilulissat
# Processing Record 10 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 11 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 7 | narsaq
# Processing Record 13 of Set 7 | ambilobe
# Processing Record 14 of Set 7 | biak
# Processing Record 15 of Set 7 | forest grove
# Processing Record 16 of Set 7 | port hedland
# Processing Record 17 of Set 7 | phrai bung
# City not found. Skipping...
# Processing Record 18 of Set 7 | sapa
# Processing Record 19 of Set 7 | victoria
# Processing Record 20 of Set 7 | zverinogolovskoye
# Processing Record 21 of Set 7 | kahului
# Processing Record 22 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 7 | youghal
# Processing Record 24 of Set 7 | litoral del san juan
# City not found. Skipping...
# Processing Record 25 of Set 7 | esperance
# Processing Record 26 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 27 of Set 7 | bowen
# Processing Record 28 of Set 7 | mayumba
# Processing Record 29 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 7 | vanimo
# Processing Record 31 of Set 7 | katubao
# Processing Record 32 of Set 7 | mizdah
# Processing Record 33 of Set 7 | hobyo
# Processing Record 34 of Set 7 | kavieng
# Processing Record 35 of Set 7 | deputatskiy
# Processing Record 36 of Set 7 | vardo
# Processing Record 37 of Set 7 | padang
# Processing Record 38 of Set 7 | tachov
# Processing Record 39 of Set 7 | kholodnyy
# Processing Record 40 of Set 7 | agadez
# Processing Record 41 of Set 7 | batemans bay
# Processing Record 42 of Set 7 | mantua
# Processing Record 43 of Set 7 | yanam
# Processing Record 44 of Set 7 | dvinskoy
# Processing Record 45 of Set 7 | sioux lookout
# Processing Record 46 of Set 7 | olinda
# Processing Record 47 of Set 7 | olafsvik
# Processing Record 48 of Set 7 | egvekinot
# Processing Record 49 of Set 7 | seddon
# Processing Record 50 of Set 7 | svetlogorsk
# Processing Record 1 of Set 8 | flinders
# Processing Record 2 of Set 8 | burnie
# Processing Record 3 of Set 8 | warangal
# Processing Record 4 of Set 8 | havoysund
# Processing Record 5 of Set 8 | pisco
# Processing Record 6 of Set 8 | tigil
# Processing Record 7 of Set 8 | kavaratti
# Processing Record 8 of Set 8 | manjakandriana
# Processing Record 9 of Set 8 | butaritari
# Processing Record 10 of Set 8 | libertador general san martin
# Processing Record 11 of Set 8 | thompson
# Processing Record 12 of Set 8 | basco
# Processing Record 13 of Set 8 | yatou
# Processing Record 14 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 8 | hamburg
# Processing Record 16 of Set 8 | rudnaya pristan
# Processing Record 17 of Set 8 | korla
# Processing Record 18 of Set 8 | chateaubelair
# Processing Record 19 of Set 8 | grindavik
# Processing Record 20 of Set 8 | teya
# Processing Record 21 of Set 8 | san quintin
# Processing Record 22 of Set 8 | yumen
# Processing Record 23 of Set 8 | florianopolis
# Processing Record 24 of Set 8 | eureka
# Processing Record 25 of Set 8 | noumea
# Processing Record 26 of Set 8 | rio gallegos
# Processing Record 27 of Set 8 | vila velha
# Processing Record 28 of Set 8 | tsabong
# Processing Record 29 of Set 8 | chopda
# Processing Record 30 of Set 8 | cooma
# Processing Record 31 of Set 8 | bandarbeyla
# Processing Record 32 of Set 8 | central point
# Processing Record 33 of Set 8 | sal rei
# Processing Record 34 of Set 8 | micheweni
# Processing Record 35 of Set 8 | kruisfontein
# Processing Record 36 of Set 8 | dhandhuka
# Processing Record 37 of Set 8 | pochutla
# Processing Record 38 of Set 8 | el prat de llobregat
# Processing Record 39 of Set 8 | codrington
# Processing Record 40 of Set 8 | tuatapere
# Processing Record 41 of Set 8 | balakhninskiy
# Processing Record 42 of Set 8 | nemuro
# Processing Record 43 of Set 8 | saryozek
# Processing Record 44 of Set 8 | zaltan
# Processing Record 45 of Set 8 | hamilton
# Processing Record 46 of Set 8 | nianzishan
# Processing Record 47 of Set 8 | montlucon
# Processing Record 48 of Set 8 | hovd
# Processing Record 49 of Set 8 | los llanos de aridane
# Processing Record 50 of Set 8 | toila
# Processing Record 1 of Set 9 | luau
# Processing Record 2 of Set 9 | alexandria
# Processing Record 3 of Set 9 | mogadishu
# Processing Record 4 of Set 9 | adrar
# Processing Record 5 of Set 9 | ketchikan
# Processing Record 6 of Set 9 | synya
# Processing Record 7 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 9 | richards bay
# Processing Record 9 of Set 9 | brownwood
# Processing Record 10 of Set 9 | takoradi
# Processing Record 11 of Set 9 | kismayo
# Processing Record 12 of Set 9 | wanaka
# Processing Record 13 of Set 9 | calvinia
# Processing Record 14 of Set 9 | port moresby
# Processing Record 15 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 9 | vavoua
# Processing Record 17 of Set 9 | nouadhibou
# Processing Record 18 of Set 9 | howard springs
# Processing Record 19 of Set 9 | cabo san lucas
# Processing Record 20 of Set 9 | isangel
# Processing Record 21 of Set 9 | boma
# Processing Record 22 of Set 9 | kemijarvi
# Processing Record 23 of Set 9 | kaeo
# Processing Record 24 of Set 9 | bara
# Processing Record 25 of Set 9 | waipawa
# Processing Record 26 of Set 9 | hastings
# Processing Record 27 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 9 | mar del plata
# Processing Record 29 of Set 9 | ratnagiri
# Processing Record 30 of Set 9 | codajas
# Processing Record 31 of Set 9 | margate
# Processing Record 32 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 9 | changli
# Processing Record 34 of Set 9 | kloulklubed
# Processing Record 35 of Set 9 | broome
# Processing Record 36 of Set 9 | metapan
# Processing Record 37 of Set 9 | saleilua
# City not found. Skipping...
# Processing Record 38 of Set 9 | aquiraz
# Processing Record 39 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 9 | trelew
# Processing Record 41 of Set 9 | mykolayivka
# Processing Record 42 of Set 9 | tarakan
# Processing Record 43 of Set 9 | araouane
# Processing Record 44 of Set 9 | pevek
# Processing Record 45 of Set 9 | berezovyy
# Processing Record 46 of Set 9 | jiexiu
# Processing Record 47 of Set 9 | bosaso
# Processing Record 48 of Set 9 | bubaque
# Processing Record 49 of Set 9 | meulaboh
# Processing Record 50 of Set 9 | saint george
# Processing Record 1 of Set 10 | goundam
# Processing Record 2 of Set 10 | shizunai
# Processing Record 3 of Set 10 | puerto penasco
# Processing Record 4 of Set 10 | qaqortoq
# Processing Record 5 of Set 10 | huntsville
# Processing Record 6 of Set 10 | saint-francois
# Processing Record 7 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 10 | senneterre
# Processing Record 9 of Set 10 | tonj
# Processing Record 10 of Set 10 | umm lajj
# Processing Record 11 of Set 10 | douentza
# Processing Record 12 of Set 10 | twentynine palms
# Processing Record 13 of Set 10 | svetlyy
# Processing Record 14 of Set 10 | tomatlan
# Processing Record 15 of Set 10 | caravelas
# Processing Record 16 of Set 10 | buala
# Processing Record 17 of Set 10 | joao pinheiro
# Processing Record 18 of Set 10 | umm kaddadah
# Processing Record 19 of Set 10 | ucluelet
# Processing Record 20 of Set 10 | nushki
# Processing Record 21 of Set 10 | pueblo nuevo vinas
# Processing Record 22 of Set 10 | hambantota
# Processing Record 23 of Set 10 | trairi
# Processing Record 24 of Set 10 | leningradskiy
# Processing Record 25 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 26 of Set 10 | dir
# Processing Record 27 of Set 10 | urdoma
# Processing Record 28 of Set 10 | mandurah
# Processing Record 29 of Set 10 | iracoubo
# Processing Record 30 of Set 10 | grand gaube
# Processing Record 31 of Set 10 | kiama
# Processing Record 32 of Set 10 | aklavik
# Processing Record 33 of Set 10 | oskemen
# Processing Record 34 of Set 10 | fredonia
# Processing Record 35 of Set 10 | riberalta
# Processing Record 36 of Set 10 | port-gentil
# Processing Record 37 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 10 | san blas
# Processing Record 39 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 40 of Set 10 | lawrenceburg
# Processing Record 41 of Set 10 | bilma
# Processing Record 42 of Set 10 | nome
# Processing Record 43 of Set 10 | pathein
# Processing Record 44 of Set 10 | pacific grove
# Processing Record 45 of Set 10 | mgandu
# Processing Record 46 of Set 10 | arinos
# Processing Record 47 of Set 10 | gat
# Processing Record 48 of Set 10 | boa vista
# Processing Record 49 of Set 10 | taldan
# Processing Record 50 of Set 10 | tongliao
# Processing Record 1 of Set 11 | arman
# Processing Record 2 of Set 11 | la grande
# Processing Record 3 of Set 11 | klyuchi
# Processing Record 4 of Set 11 | vangaindrano
# Processing Record 5 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 11 | seoul
# Processing Record 7 of Set 11 | abalak
# Processing Record 8 of Set 11 | kanlagay
# Processing Record 9 of Set 11 | singkawang
# Processing Record 10 of Set 11 | krasnoselkup
# Processing Record 11 of Set 11 | ewa beach
# Processing Record 12 of Set 11 | sao joao da ponte
# Processing Record 13 of Set 11 | santa vitoria do palmar
# Processing Record 14 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 15 of Set 11 | dingle
# Processing Record 16 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 11 | yar-sale
# Processing Record 18 of Set 11 | usinsk
# Processing Record 19 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 20 of Set 11 | kawalu
# Processing Record 21 of Set 11 | xiaoshi
# Processing Record 22 of Set 11 | ler
# Processing Record 23 of Set 11 | akdepe
# Processing Record 24 of Set 11 | shaowu
# Processing Record 25 of Set 11 | leeton
# Processing Record 26 of Set 11 | jam sahib
# Processing Record 27 of Set 11 | san ignacio
# Processing Record 28 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 30 of Set 11 | baijiantan
# Processing Record 31 of Set 11 | novyy urengoy
# Processing Record 32 of Set 11 | mazatlan
# Processing Record 33 of Set 11 | buraydah
# Processing Record 34 of Set 11 | tabou
# Processing Record 35 of Set 11 | okhotsk
# Processing Record 36 of Set 11 | dongsheng
# Processing Record 37 of Set 11 | beloha
# Processing Record 38 of Set 11 | mahajanga
# Processing Record 39 of Set 11 | port-cartier
# Processing Record 40 of Set 11 | jacareacanga
# Processing Record 41 of Set 11 | kijang
# Processing Record 42 of Set 11 | zwedru
# Processing Record 43 of Set 11 | letlhakeng
# Processing Record 44 of Set 11 | auki
# Processing Record 45 of Set 11 | la ronge
# Processing Record 46 of Set 11 | noshiro
# Processing Record 47 of Set 11 | chico
# Processing Record 48 of Set 11 | qafsah
# City not found. Skipping...
# Processing Record 49 of Set 11 | denpasar
# Processing Record 50 of Set 11 | numan
# Processing Record 1 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 12 | najran
# Processing Record 3 of Set 12 | ust-omchug
# Processing Record 4 of Set 12 | pemangkat
# Processing Record 5 of Set 12 | krasnoarmeysk
# Processing Record 6 of Set 12 | churapcha
# Processing Record 7 of Set 12 | ranong
# Processing Record 8 of Set 12 | sakakah
# Processing Record 9 of Set 12 | eisenerz
# Processing Record 10 of Set 12 | axim
# Processing Record 11 of Set 12 | idrinskoye
# Processing Record 12 of Set 12 | les cayes
# Processing Record 13 of Set 12 | tura
# Processing Record 14 of Set 12 | rudnogorsk
# Processing Record 15 of Set 12 | koraput
# Processing Record 16 of Set 12 | beni suef
# Processing Record 17 of Set 12 | east wenatchee bench
# Processing Record 18 of Set 12 | villazon
# Processing Record 19 of Set 12 | vestmannaeyjar
# Processing Record 20 of Set 12 | balkhash
# Processing Record 21 of Set 12 | bayir
# Processing Record 22 of Set 12 | ray
# Processing Record 23 of Set 12 | klichka
# Processing Record 24 of Set 12 | miri
# Processing Record 25 of Set 12 | teahupoo
# Processing Record 26 of Set 12 | ixtapa
# Processing Record 27 of Set 12 | itaituba
# Processing Record 28 of Set 12 | necochea
# Processing Record 29 of Set 12 | eskilstuna
# Processing Record 30 of Set 12 | urumqi
# Processing Record 31 of Set 12 | bor
# Processing Record 32 of Set 12 | cockburn town
# Processing Record 33 of Set 12 | diffa
# Processing Record 34 of Set 12 | marovoay
# Processing Record 35 of Set 12 | guanajuato
# Processing Record 36 of Set 12 | novikovo
# Processing Record 37 of Set 12 | krasavino
# Processing Record 38 of Set 12 | salalah
# Processing Record 39 of Set 12 | beidao
# Processing Record 40 of Set 12 | simplicio mendes
# Processing Record 41 of Set 12 | taoudenni
# Processing Record 42 of Set 12 | quatre cocos
# Processing Record 43 of Set 12 | dungarpur
# Processing Record 44 of Set 12 | derbent
# Processing Record 45 of Set 12 | chervishevo
# Processing Record 46 of Set 12 | port lincoln
# Processing Record 47 of Set 12 | lohja
# Processing Record 48 of Set 12 | kpandu
# Processing Record 49 of Set 12 | kralendijk
# Processing Record 50 of Set 12 | cururupu
# Processing Record 1 of Set 13 | newtownards
# Processing Record 2 of Set 13 | gambela
# Processing Record 3 of Set 13 | bocana
# Processing Record 4 of Set 13 | mtambile
# Processing Record 5 of Set 13 | catuday
# Processing Record 6 of Set 13 | makanya
# Processing Record 7 of Set 13 | ashtian
# Processing Record 8 of Set 13 | saint joseph
# Processing Record 9 of Set 13 | garowe
# Processing Record 10 of Set 13 | dzhankoy
# Processing Record 11 of Set 13 | handwara
# City not found. Skipping...
# Processing Record 12 of Set 13 | kutahya
# Processing Record 13 of Set 13 | matagami
# Processing Record 14 of Set 13 | coffs harbour
# Processing Record 15 of Set 13 | nedryhayliv
# Processing Record 16 of Set 13 | kaa-khem
# Processing Record 17 of Set 13 | acoyapa
# Processing Record 18 of Set 13 | dunmore town
# Processing Record 19 of Set 13 | sao jose da coroa grande
# Processing Record 20 of Set 13 | gerash
# Processing Record 21 of Set 13 | uray
# Processing Record 22 of Set 13 | corrales
# Processing Record 23 of Set 13 | dunedin
# Processing Record 24 of Set 13 | korhogo
# Processing Record 25 of Set 13 | mayo
# Processing Record 26 of Set 13 | parkes
# Processing Record 27 of Set 13 | ferme-neuve
# Processing Record 28 of Set 13 | san cristobal
# Processing Record 29 of Set 13 | thilogne
# City not found. Skipping...
# Processing Record 30 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 31 of Set 13 | santa cruz
# Processing Record 32 of Set 13 | saint-paul
# Processing Record 33 of Set 13 | raudeberg
# Processing Record 34 of Set 13 | mortka
# Processing Record 35 of Set 13 | jaru
# Processing Record 36 of Set 13 | ipatovo
# Processing Record 37 of Set 13 | owatonna
# Processing Record 38 of Set 13 | launceston
# Processing Record 39 of Set 13 | gardez
# Processing Record 40 of Set 13 | chulym
# Processing Record 41 of Set 13 | lorengau
# Processing Record 42 of Set 13 | yokadouma
# Processing Record 43 of Set 13 | narok
# Processing Record 44 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 45 of Set 13 | chifeng
# Processing Record 46 of Set 13 | coquimbo
# Processing Record 47 of Set 13 | radevormwald
# Processing Record 48 of Set 13 | yangjiang
# Processing Record 49 of Set 13 | krasnokamensk
# Processing Record 50 of Set 13 | porto santo
# Processing Record 1 of Set 14 | biri
# Processing Record 2 of Set 14 | kargopol
# Processing Record 3 of Set 14 | qui nhon
# Processing Record 4 of Set 14 | vetluzhskiy
# Processing Record 5 of Set 14 | barcelos
# Processing Record 6 of Set 14 | mantena
# Processing Record 7 of Set 14 | grants pass
# Processing Record 8 of Set 14 | pizarro
# Processing Record 9 of Set 14 | chervona sloboda
# Processing Record 10 of Set 14 | igarka
# Processing Record 11 of Set 14 | port hardy
# Processing Record 12 of Set 14 | mount isa
# Processing Record 13 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 14 of Set 14 | waingapu
# Processing Record 15 of Set 14 | bichura
# Processing Record 16 of Set 14 | dawei
# Processing Record 17 of Set 14 | ngunguru
# Processing Record 18 of Set 14 | mayna
# Processing Record 19 of Set 14 | copiapo
# Processing Record 20 of Set 14 | lasem
# Processing Record 21 of Set 14 | marienburg
# Processing Record 22 of Set 14 | anguillara sabazia
# Processing Record 23 of Set 14 | kota belud
# Processing Record 24 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 14 | sao joao da barra
# Processing Record 26 of Set 14 | jiangyou
# Processing Record 27 of Set 14 | luwuk
# Processing Record 28 of Set 14 | abu dhabi
# Processing Record 29 of Set 14 | alghero
# Processing Record 30 of Set 14 | riyadh
# Processing Record 31 of Set 14 | muisne
# Processing Record 32 of Set 14 | guigue
# Processing Record 33 of Set 14 | bambanglipuro
# Processing Record 34 of Set 14 | neryungri
# Processing Record 35 of Set 14 | muros
# Processing Record 36 of Set 14 | igunga
# Processing Record 37 of Set 14 | kallupatti
# Processing Record 38 of Set 14 | tarko-sale
# Processing Record 39 of Set 14 | bathsheba
# Processing Record 40 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 14 | san jose
# Processing Record 42 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 43 of Set 14 | kishi
# Processing Record 44 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 14 | gamba
# Processing Record 46 of Set 14 | peringat
# Processing Record 47 of Set 14 | strezhevoy
# Processing Record 48 of Set 14 | balabac
# Processing Record 49 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 14 | contamana
# Processing Record 1 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 15 | nang rong
# Processing Record 3 of Set 15 | urucui
# Processing Record 4 of Set 15 | tevriz
# Processing Record 5 of Set 15 | ust-nera
# Processing Record 6 of Set 15 | celestun
# Processing Record 7 of Set 15 | villa bruzual
# Processing Record 8 of Set 15 | misratah
# Processing Record 9 of Set 15 | kirakira
# Processing Record 10 of Set 15 | kamenka
# Processing Record 11 of Set 15 | burns lake
# Processing Record 12 of Set 15 | san jeronimo
# Processing Record 13 of Set 15 | galle
# Processing Record 14 of Set 15 | erdaojiang
# Processing Record 15 of Set 15 | tessalit
# Processing Record 16 of Set 15 | sawtell
# Processing Record 17 of Set 15 | sishui
# Processing Record 18 of Set 15 | norfolk
# Processing Record 19 of Set 15 | kushiro
# Processing Record 20 of Set 15 | chapais
# Processing Record 21 of Set 15 | zherdevka
# Processing Record 22 of Set 15 | baruun-urt
# Processing Record 23 of Set 15 | urucara
# Processing Record 24 of Set 15 | laranjal paulista
# Processing Record 25 of Set 15 | tamiahua
# Processing Record 26 of Set 15 | graciano sanchez
# Processing Record 27 of Set 15 | xichang
# Processing Record 28 of Set 15 | ikalamavony
# Processing Record 29 of Set 15 | khasan
# Processing Record 30 of Set 15 | basoko
# Processing Record 31 of Set 15 | reporoa
# Processing Record 32 of Set 15 | ramona
# Processing Record 33 of Set 15 | tungor
# Processing Record 34 of Set 15 | katangli
# Processing Record 35 of Set 15 | kang
# Processing Record 36 of Set 15 | talakan
# Processing Record 37 of Set 15 | kidal
# Processing Record 38 of Set 15 | tawau
# Processing Record 39 of Set 15 | abaete
# Processing Record 40 of Set 15 | opuwo
# Processing Record 41 of Set 15 | hervey bay
# Processing Record 42 of Set 15 | yulara
# Processing Record 43 of Set 15 | novaya bryan
# Processing Record 44 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 45 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 15 | sao desiderio
# Processing Record 47 of Set 15 | bamako
# Processing Record 48 of Set 15 | curico
# Processing Record 49 of Set 15 | derzhavinsk
# Processing Record 50 of Set 15 | shubarkuduk
# Processing Record 1 of Set 16 | moerai
# Processing Record 2 of Set 16 | upata
# Processing Record 3 of Set 16 | zhezkazgan
# Processing Record 4 of Set 16 | sembe
# Processing Record 5 of Set 16 | comodoro rivadavia
# Processing Record 6 of Set 16 | vezirkopru
# Processing Record 7 of Set 16 | tiznit
# Processing Record 8 of Set 16 | bonavista
# Processing Record 9 of Set 16 | koutsouras
# Processing Record 10 of Set 16 | montepuez
# Processing Record 11 of Set 16 | emerald
# Processing Record 12 of Set 16 | mindelo
# Processing Record 13 of Set 16 | santiago del estero
# Processing Record 14 of Set 16 | manono
# Processing Record 15 of Set 16 | griffith
# Processing Record 16 of Set 16 | si racha
# Processing Record 17 of Set 16 | shebunino
# Processing Record 18 of Set 16 | nouakchott
# Processing Record 19 of Set 16 | vryheid
# Processing Record 20 of Set 16 | kerrville
# Processing Record 21 of Set 16 | nakusp
# Processing Record 22 of Set 16 | williston
# Processing Record 23 of Set 16 | jiaojiang
# Processing Record 24 of Set 16 | rivera
# Processing Record 25 of Set 16 | mana
# Processing Record 26 of Set 16 | santa maria
# Processing Record 27 of Set 16 | onega
# Processing Record 28 of Set 16 | sola
# Processing Record 29 of Set 16 | tottori
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 715

# %% [markdown]
# ### Add the data to a new DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Constitucion -35.3333  -72.4167     61.05        57         100
# 1         Qaanaaq  77.4840  -69.3632     14.31        71         100
# 2  Gusinoye Ozero  51.1144  106.2614     34.68        78          77
# 3        Sisimiut  66.9395  -53.6735     32.97        98         100
# 4          Albany  42.6001  -73.9662     62.60        55          40
# 5         Rikitea -23.1203 -134.9692     77.16        70         100
# 6         Camacha  33.0833  -16.3333     68.00        68          20
# 7    Puerto Ayora  -0.7393  -90.3518     77.00        94          75
# 8    Beringovskiy  63.0500  179.3167      5.76        94         100
# 9         Mataura -46.1927  168.8643     46.99        85         100
#
#    Wind Speed Country                 Date Current Description
# 0        7.92      CL  2021-04-09 15:06:03     overcast clouds
# 1        4.50      GL  2021-04-09 15:06:04     overcast clouds
# 2        5.30      RU  2021-04-09 15:06:04       broken clouds
# 3       25.08      GL  2021-04-09 15:06:05                snow
# 4        9.22      US  2021-04-09 15:03:41    scattered clouds
# 5        8.99      PF  2021-04-09 15:06:05     overcast clouds
# 6       13.80      PT  2021-04-09 15:04:36          few clouds
# 7        3.44      EC  2021-04-09 15:06:06          light rain
# 8        8.75      RU  2021-04-09 15:06:06     overcast clouds
# 9        3.00      NZ  2021-04-09 15:06:06     overcast clouds

# %% [markdown]
# ### Adjust the column order

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Constitucion      CL -35.3333  -72.4167     61.05        57         100
# 1         Qaanaaq      GL  77.4840  -69.3632     14.31        71         100
# 2  Gusinoye Ozero      RU  51.1144  106.2614     34.68        78          77
# 3        Sisimiut      GL  66.9395  -53.6735     32.97        98         100
# 4          Albany      US  42.6001  -73.9662     62.60        55          40
# 5         Rikitea      PF -23.1203 -134.9692     77.16        70         100
# 6         Camacha      PT  33.0833  -16.3333     68.00        68          20
# 7    Puerto Ayora      EC  -0.7393  -90.3518     77.00        94          75
# 8    Beringovskiy      RU  63.0500  179.3167      5.76        94         100
# 9         Mataura      NZ -46.1927  168.8643     46.99        85         100
#
#    Wind Speed Current Description
# 0        7.92     overcast clouds
# 1        4.50     overcast clouds
# 2        5.30       broken clouds
# 3       25.08                snow
# 4        9.22    scattered clouds
# 5        8.99     overcast clouds
# 6       13.80          few clouds
# 7        3.44          light rain
# 8        8.75     overcast clouds
# 9        3.00     overcast clouds

# %% [markdown]
# ### Export the DataFrame as a CSV file

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
