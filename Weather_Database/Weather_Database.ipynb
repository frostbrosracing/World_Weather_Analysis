# %% [markdown]
# ### Import the dependencies, libraries, modules, and the weather_api_key

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Add the requests library from Anaconda
import requests
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key

# %% [markdown]
# ### Create a set of 2,000 random latitudes and longitudes

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### Get the nearest city using the citypy module

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %% [markdown]
# ### Perform an API call with the OpenWeatherMap

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1113308864fb7c97390b51d68b7ee217

# %% [markdown]
# ### Retrieve the following information from the API call: Latitude and Longitude, Maximum temperature, Percent humidity, Percent cloudiness, Wind speed, Weather description

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | alice springs
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | sakaiminato
# Processing Record 5 of Set 1 | iracoubo
# Processing Record 6 of Set 1 | guerrero negro
# Processing Record 7 of Set 1 | hagere selam
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 1 | walvis bay
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | barmer
# Processing Record 14 of Set 1 | el bagre
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | saint augustine
# Processing Record 21 of Set 1 | palora
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | maamba
# Processing Record 24 of Set 1 | lithgow
# Processing Record 25 of Set 1 | manggar
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | angoram
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | cabo san lucas
# Processing Record 31 of Set 1 | baruun-urt
# Processing Record 32 of Set 1 | iqaluit
# Processing Record 33 of Set 1 | fez
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | pratapgarh
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | slave lake
# Processing Record 38 of Set 1 | lyngseidet
# Processing Record 39 of Set 1 | burns lake
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | east london
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | waingapu
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | kahului
# Processing Record 48 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 1 | vavozh
# Processing Record 50 of Set 1 | chik
# Processing Record 1 of Set 2 | qaqortoq
# Processing Record 2 of Set 2 | chokurdakh
# Processing Record 3 of Set 2 | dingle
# Processing Record 4 of Set 2 | laguna
# Processing Record 5 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | meilu
# City not found. Skipping...
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | olafsvik
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 2 | cidreira
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | gigmoto
# Processing Record 19 of Set 2 | bengkulu
# Processing Record 20 of Set 2 | alyangula
# Processing Record 21 of Set 2 | khani
# Processing Record 22 of Set 2 | sompeta
# Processing Record 23 of Set 2 | mount gambier
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | lasa
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 2 | touros
# Processing Record 29 of Set 2 | maningrida
# Processing Record 30 of Set 2 | bandarbeyla
# Processing Record 31 of Set 2 | ulladulla
# Processing Record 32 of Set 2 | epinal
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | pacific grove
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | adre
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | ustye
# Processing Record 39 of Set 2 | key west
# Processing Record 40 of Set 2 | torbay
# Processing Record 41 of Set 2 | nabire
# Processing Record 42 of Set 2 | lazaro cardenas
# Processing Record 43 of Set 2 | lewistown
# Processing Record 44 of Set 2 | tashla
# Processing Record 45 of Set 2 | sangar
# Processing Record 46 of Set 2 | marsh harbour
# Processing Record 47 of Set 2 | bonthe
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | abong mbang
# Processing Record 50 of Set 2 | kargasok
# Processing Record 1 of Set 3 | perevolotskiy
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | victoria
# Processing Record 4 of Set 3 | taoudenni
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | the pas
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | gewane
# Processing Record 9 of Set 3 | trincomalee
# Processing Record 10 of Set 3 | haines junction
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | candido mendes
# Processing Record 14 of Set 3 | loa janan
# Processing Record 15 of Set 3 | oistins
# Processing Record 16 of Set 3 | vestbygda
# City not found. Skipping...
# Processing Record 17 of Set 3 | tera
# Processing Record 18 of Set 3 | pakwach
# City not found. Skipping...
# Processing Record 19 of Set 3 | tuatapere
# Processing Record 20 of Set 3 | barrow
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | port-cartier
# Processing Record 23 of Set 3 | masvingo
# Processing Record 24 of Set 3 | huarmey
# Processing Record 25 of Set 3 | tual
# Processing Record 26 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 27 of Set 3 | smithers
# Processing Record 28 of Set 3 | belmonte
# Processing Record 29 of Set 3 | pundaguitan
# Processing Record 30 of Set 3 | dubti
# Processing Record 31 of Set 3 | mackay
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | khatanga
# Processing Record 34 of Set 3 | gotsu
# Processing Record 35 of Set 3 | roald
# Processing Record 36 of Set 3 | zhezkazgan
# Processing Record 37 of Set 3 | padang
# Processing Record 38 of Set 3 | coahuayana
# Processing Record 39 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 3 | along
# Processing Record 41 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 3 | esna
# Processing Record 43 of Set 3 | srednekolymsk
# Processing Record 44 of Set 3 | kathu
# Processing Record 45 of Set 3 | airai
# Processing Record 46 of Set 3 | cumana
# Processing Record 47 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 3 | sao filipe
# Processing Record 49 of Set 3 | tyret pervaya
# Processing Record 50 of Set 3 | henties bay
# Processing Record 1 of Set 4 | hithadhoo
# Processing Record 2 of Set 4 | hasaki
# Processing Record 3 of Set 4 | matara
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | antofagasta
# Processing Record 6 of Set 4 | mahebourg
# Processing Record 7 of Set 4 | carthage
# Processing Record 8 of Set 4 | tourlaville
# Processing Record 9 of Set 4 | yaan
# Processing Record 10 of Set 4 | lethem
# Processing Record 11 of Set 4 | klaksvik
# Processing Record 12 of Set 4 | port elizabeth
# Processing Record 13 of Set 4 | port hardy
# Processing Record 14 of Set 4 | palauig
# Processing Record 15 of Set 4 | fort frances
# Processing Record 16 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 4 | arraial do cabo
# Processing Record 18 of Set 4 | ulverstone
# Processing Record 19 of Set 4 | vaini
# Processing Record 20 of Set 4 | sola
# Processing Record 21 of Set 4 | vila franca do campo
# Processing Record 22 of Set 4 | santa cruz del sur
# Processing Record 23 of Set 4 | saint anthony
# Processing Record 24 of Set 4 | alekseyevskaya
# Processing Record 25 of Set 4 | knysna
# Processing Record 26 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 4 | te anau
# Processing Record 28 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 4 | biloela
# Processing Record 30 of Set 4 | conway
# Processing Record 31 of Set 4 | komsomolskiy
# Processing Record 32 of Set 4 | leningradskiy
# Processing Record 33 of Set 4 | havre-saint-pierre
# Processing Record 34 of Set 4 | nanortalik
# Processing Record 35 of Set 4 | mar del plata
# Processing Record 36 of Set 4 | ucluelet
# Processing Record 37 of Set 4 | bubaque
# Processing Record 38 of Set 4 | college
# Processing Record 39 of Set 4 | santa isabel do rio negro
# Processing Record 40 of Set 4 | evensk
# Processing Record 41 of Set 4 | kalmunai
# Processing Record 42 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 4 | ronne
# Processing Record 45 of Set 4 | hamilton
# Processing Record 46 of Set 4 | vestmannaeyjar
# Processing Record 47 of Set 4 | chastoozerye
# City not found. Skipping...
# Processing Record 48 of Set 4 | comodoro rivadavia
# Processing Record 49 of Set 4 | la palma
# Processing Record 50 of Set 4 | chicama
# Processing Record 1 of Set 5 | bethel
# Processing Record 2 of Set 5 | kuching
# Processing Record 3 of Set 5 | diamantino
# Processing Record 4 of Set 5 | salamiyah
# Processing Record 5 of Set 5 | inirida
# Processing Record 6 of Set 5 | sao joao da barra
# Processing Record 7 of Set 5 | ankang
# Processing Record 8 of Set 5 | victor harbor
# Processing Record 9 of Set 5 | hovd
# Processing Record 10 of Set 5 | high level
# Processing Record 11 of Set 5 | tiksi
# Processing Record 12 of Set 5 | kodiak
# Processing Record 13 of Set 5 | boueni
# Processing Record 14 of Set 5 | himare
# Processing Record 15 of Set 5 | flin flon
# Processing Record 16 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | petatlan
# Processing Record 19 of Set 5 | samana
# Processing Record 20 of Set 5 | sorland
# Processing Record 21 of Set 5 | codrington
# Processing Record 22 of Set 5 | kieta
# Processing Record 23 of Set 5 | dunedin
# Processing Record 24 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 25 of Set 5 | assela
# City not found. Skipping...
# Processing Record 26 of Set 5 | bouca
# Processing Record 27 of Set 5 | anzoategui
# Processing Record 28 of Set 5 | santa maria
# Processing Record 29 of Set 5 | khandyga
# Processing Record 30 of Set 5 | dickson
# Processing Record 31 of Set 5 | megion
# Processing Record 32 of Set 5 | mogok
# Processing Record 33 of Set 5 | saint-georges
# Processing Record 34 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 35 of Set 5 | bloomfield
# Processing Record 36 of Set 5 | mikhaylovka
# Processing Record 37 of Set 5 | cortez
# Processing Record 38 of Set 5 | krasnyy kurgan
# Processing Record 39 of Set 5 | atambua
# Processing Record 40 of Set 5 | imbituba
# Processing Record 41 of Set 5 | upernavik
# Processing Record 42 of Set 5 | mehamn
# Processing Record 43 of Set 5 | zeya
# Processing Record 44 of Set 5 | longyan
# Processing Record 45 of Set 5 | taltal
# Processing Record 46 of Set 5 | robe
# Processing Record 47 of Set 5 | douglas
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | hinton
# Processing Record 50 of Set 5 | norman wells
# Processing Record 1 of Set 6 | severnoye
# Processing Record 2 of Set 6 | gidam
# Processing Record 3 of Set 6 | naze
# Processing Record 4 of Set 6 | beringovskiy
# Processing Record 5 of Set 6 | qasigiannguit
# Processing Record 6 of Set 6 | maniwaki
# Processing Record 7 of Set 6 | lingao
# Processing Record 8 of Set 6 | tuktoyaktuk
# Processing Record 9 of Set 6 | sitka
# Processing Record 10 of Set 6 | katangli
# Processing Record 11 of Set 6 | tatawin
# Processing Record 12 of Set 6 | metro
# Processing Record 13 of Set 6 | lavrentiya
# Processing Record 14 of Set 6 | guerande
# Processing Record 15 of Set 6 | half moon bay
# Processing Record 16 of Set 6 | port blair
# Processing Record 17 of Set 6 | vila velha
# Processing Record 18 of Set 6 | hobyo
# Processing Record 19 of Set 6 | san patricio
# Processing Record 20 of Set 6 | normandin
# Processing Record 21 of Set 6 | saint joseph
# Processing Record 22 of Set 6 | mount isa
# Processing Record 23 of Set 6 | tombouctou
# Processing Record 24 of Set 6 | hambantota
# Processing Record 25 of Set 6 | cherskiy
# Processing Record 26 of Set 6 | wagar
# Processing Record 27 of Set 6 | bathsheba
# Processing Record 28 of Set 6 | rocha
# Processing Record 29 of Set 6 | jalu
# Processing Record 30 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 6 | bud
# Processing Record 32 of Set 6 | conceicao do araguaia
# Processing Record 33 of Set 6 | vardo
# Processing Record 34 of Set 6 | bow island
# Processing Record 35 of Set 6 | nome
# Processing Record 36 of Set 6 | alofi
# Processing Record 37 of Set 6 | broome
# Processing Record 38 of Set 6 | bereda
# Processing Record 39 of Set 6 | zhangye
# Processing Record 40 of Set 6 | saldanha
# Processing Record 41 of Set 6 | coulihaut
# City not found. Skipping...
# Processing Record 42 of Set 6 | vallenar
# Processing Record 43 of Set 6 | narsaq
# Processing Record 44 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 6 | kruisfontein
# Processing Record 46 of Set 6 | gornopravdinsk
# Processing Record 47 of Set 6 | yurla
# Processing Record 48 of Set 6 | carutapera
# Processing Record 49 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 6 | muzaffarabad
# Processing Record 1 of Set 7 | quesnel
# Processing Record 2 of Set 7 | erenhot
# Processing Record 3 of Set 7 | porto novo
# Processing Record 4 of Set 7 | bambous virieux
# Processing Record 5 of Set 7 | otradnoye
# Processing Record 6 of Set 7 | geraldton
# Processing Record 7 of Set 7 | raga
# Processing Record 8 of Set 7 | tres arroyos
# Processing Record 9 of Set 7 | mayo
# Processing Record 10 of Set 7 | palmer
# Processing Record 11 of Set 7 | rockland
# Processing Record 12 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 7 | wekiva springs
# Processing Record 14 of Set 7 | rawson
# Processing Record 15 of Set 7 | sao sebastiao
# Processing Record 16 of Set 7 | tezu
# Processing Record 17 of Set 7 | talnakh
# Processing Record 18 of Set 7 | lakes entrance
# Processing Record 19 of Set 7 | lac du bonnet
# Processing Record 20 of Set 7 | luderitz
# Processing Record 21 of Set 7 | brae
# Processing Record 22 of Set 7 | gao
# Processing Record 23 of Set 7 | nemuro
# Processing Record 24 of Set 7 | asfi
# Processing Record 25 of Set 7 | turukhansk
# Processing Record 26 of Set 7 | severnyy
# Processing Record 27 of Set 7 | taman
# Processing Record 28 of Set 7 | aykhal
# Processing Record 29 of Set 7 | kiruna
# Processing Record 30 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 7 | chernyshevskiy
# Processing Record 32 of Set 7 | jaru
# Processing Record 33 of Set 7 | colares
# Processing Record 34 of Set 7 | ancud
# Processing Record 35 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 7 | vestmanna
# Processing Record 37 of Set 7 | kholodnyy
# Processing Record 38 of Set 7 | batemans bay
# Processing Record 39 of Set 7 | lincoln
# Processing Record 40 of Set 7 | berbera
# Processing Record 41 of Set 7 | saint-pierre
# Processing Record 42 of Set 7 | teya
# Processing Record 43 of Set 7 | fortuna
# Processing Record 44 of Set 7 | gizo
# Processing Record 45 of Set 7 | lompoc
# Processing Record 46 of Set 7 | erzin
# Processing Record 47 of Set 7 | nizhniy kuranakh
# Processing Record 48 of Set 7 | kachikau
# City not found. Skipping...
# Processing Record 49 of Set 7 | arras
# Processing Record 50 of Set 7 | oga
# Processing Record 1 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 2 of Set 8 | bitung
# Processing Record 3 of Set 8 | wynyard
# Processing Record 4 of Set 8 | meulaboh
# Processing Record 5 of Set 8 | guano
# Processing Record 6 of Set 8 | parambu
# Processing Record 7 of Set 8 | russell
# Processing Record 8 of Set 8 | muzaffarpur
# Processing Record 9 of Set 8 | adrar
# Processing Record 10 of Set 8 | necochea
# Processing Record 11 of Set 8 | sibiti
# Processing Record 12 of Set 8 | flagstaff
# Processing Record 13 of Set 8 | ruteng
# Processing Record 14 of Set 8 | bulawayo
# Processing Record 15 of Set 8 | kidal
# Processing Record 16 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 17 of Set 8 | salalah
# Processing Record 18 of Set 8 | port lincoln
# Processing Record 19 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 8 | konya
# Processing Record 21 of Set 8 | grindavik
# Processing Record 22 of Set 8 | lubumbashi
# Processing Record 23 of Set 8 | pueblo nuevo
# Processing Record 24 of Set 8 | kashin
# Processing Record 25 of Set 8 | najran
# Processing Record 26 of Set 8 | los llanos de aridane
# Processing Record 27 of Set 8 | sirmaur
# Processing Record 28 of Set 8 | zaraza
# Processing Record 29 of Set 8 | hofn
# Processing Record 30 of Set 8 | castlemaine
# Processing Record 31 of Set 8 | oktyabrskoye
# Processing Record 32 of Set 8 | lucapa
# Processing Record 33 of Set 8 | truckee
# Processing Record 34 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 35 of Set 8 | abha
# Processing Record 36 of Set 8 | trinidad
# Processing Record 37 of Set 8 | bartlett
# Processing Record 38 of Set 8 | souillac
# Processing Record 39 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 40 of Set 8 | amvrosiyivka
# Processing Record 41 of Set 8 | coihaique
# Processing Record 42 of Set 8 | tala
# Processing Record 43 of Set 8 | almeirim
# Processing Record 44 of Set 8 | ismailia
# Processing Record 45 of Set 8 | maniitsoq
# Processing Record 46 of Set 8 | kavaratti
# Processing Record 47 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 8 | suihua
# Processing Record 49 of Set 8 | lorvao
# Processing Record 50 of Set 8 | machiques
# Processing Record 1 of Set 9 | paldiski
# Processing Record 2 of Set 9 | gamboma
# Processing Record 3 of Set 9 | oboyan
# Processing Record 4 of Set 9 | sawtell
# Processing Record 5 of Set 9 | bandar-e anzali
# Processing Record 6 of Set 9 | coxim
# Processing Record 7 of Set 9 | umm lajj
# Processing Record 8 of Set 9 | ornskoldsvik
# Processing Record 9 of Set 9 | sawakin
# Processing Record 10 of Set 9 | shaoxing
# Processing Record 11 of Set 9 | griffith
# Processing Record 12 of Set 9 | nosy varika
# Processing Record 13 of Set 9 | korla
# Processing Record 14 of Set 9 | oksfjord
# Processing Record 15 of Set 9 | kamenka
# Processing Record 16 of Set 9 | grand gaube
# Processing Record 17 of Set 9 | mogocha
# Processing Record 18 of Set 9 | tilichiki
# Processing Record 19 of Set 9 | nouadhibou
# Processing Record 20 of Set 9 | fontenay-le-comte
# Processing Record 21 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 9 | presidente dutra
# Processing Record 23 of Set 9 | cayenne
# Processing Record 24 of Set 9 | uige
# Processing Record 25 of Set 9 | kurchum
# Processing Record 26 of Set 9 | hami
# Processing Record 27 of Set 9 | krasnoselkup
# Processing Record 28 of Set 9 | denver
# Processing Record 29 of Set 9 | erdenet
# Processing Record 30 of Set 9 | auki
# Processing Record 31 of Set 9 | kailua
# Processing Record 32 of Set 9 | christchurch
# Processing Record 33 of Set 9 | banda aceh
# Processing Record 34 of Set 9 | qianguo
# Processing Record 35 of Set 9 | margate
# Processing Record 36 of Set 9 | beitbridge
# Processing Record 37 of Set 9 | anadyr
# Processing Record 38 of Set 9 | rodrigues alves
# Processing Record 39 of Set 9 | manzhouli
# Processing Record 40 of Set 9 | verkhnevilyuysk
# Processing Record 41 of Set 9 | bonavista
# Processing Record 42 of Set 9 | melekhovskaya
# City not found. Skipping...
# Processing Record 43 of Set 9 | isangel
# Processing Record 44 of Set 9 | asau
# Processing Record 45 of Set 9 | kodinsk
# Processing Record 46 of Set 9 | killybegs
# Processing Record 47 of Set 9 | yertsevo
# Processing Record 48 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 9 | nouakchott
# Processing Record 1 of Set 10 | yinchuan
# Processing Record 2 of Set 10 | izumo
# Processing Record 3 of Set 10 | kontagora
# Processing Record 4 of Set 10 | apsheronsk
# Processing Record 5 of Set 10 | yumen
# Processing Record 6 of Set 10 | puerto concordia
# Processing Record 7 of Set 10 | herat
# Processing Record 8 of Set 10 | seoul
# Processing Record 9 of Set 10 | zaraysk
# Processing Record 10 of Set 10 | kuala terengganu
# Processing Record 11 of Set 10 | tuzha
# Processing Record 12 of Set 10 | kathmandu
# Processing Record 13 of Set 10 | suluq
# Processing Record 14 of Set 10 | guaruja
# Processing Record 15 of Set 10 | danilovka
# Processing Record 16 of Set 10 | guantanamo
# Processing Record 17 of Set 10 | sao joao dos patos
# Processing Record 18 of Set 10 | yulara
# Processing Record 19 of Set 10 | dmitrovsk-orlovskiy
# Processing Record 20 of Set 10 | siwani
# City not found. Skipping...
# Processing Record 21 of Set 10 | san juan del parana
# Processing Record 22 of Set 10 | hashtgerd
# Processing Record 23 of Set 10 | ustrzyki dolne
# Processing Record 24 of Set 10 | itoman
# Processing Record 25 of Set 10 | aleksandrovka
# Processing Record 26 of Set 10 | morelia
# Processing Record 27 of Set 10 | lagos
# Processing Record 28 of Set 10 | kyabe
# Processing Record 29 of Set 10 | hirara
# Processing Record 30 of Set 10 | miandrivazo
# Processing Record 31 of Set 10 | belyy yar
# Processing Record 32 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 33 of Set 10 | puri
# Processing Record 34 of Set 10 | port moresby
# Processing Record 35 of Set 10 | mayari
# City not found. Skipping...
# Processing Record 36 of Set 10 | marystown
# Processing Record 37 of Set 10 | hualmay
# Processing Record 38 of Set 10 | union
# Processing Record 39 of Set 10 | humberto de campos
# Processing Record 40 of Set 10 | aybak
# City not found. Skipping...
# Processing Record 41 of Set 10 | ontario
# Processing Record 42 of Set 10 | acari
# Processing Record 43 of Set 10 | mataram
# Processing Record 44 of Set 10 | george
# Processing Record 45 of Set 10 | tir pol
# City not found. Skipping...
# Processing Record 46 of Set 10 | valparaiso
# Processing Record 47 of Set 10 | esperance
# Processing Record 48 of Set 10 | ratnagiri
# Processing Record 49 of Set 10 | rayon
# Processing Record 50 of Set 10 | vila
# Processing Record 1 of Set 11 | laramie
# Processing Record 2 of Set 11 | ambon
# Processing Record 3 of Set 11 | enterprise
# Processing Record 4 of Set 11 | broken hill
# Processing Record 5 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 6 of Set 11 | bassar
# Processing Record 7 of Set 11 | tuban
# Processing Record 8 of Set 11 | pitimbu
# Processing Record 9 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 11 | bumba
# Processing Record 12 of Set 11 | nhulunbuy
# Processing Record 13 of Set 11 | salcia
# Processing Record 14 of Set 11 | nyurba
# Processing Record 15 of Set 11 | neryungri
# Processing Record 16 of Set 11 | rivadavia
# Processing Record 17 of Set 11 | quatre cocos
# Processing Record 18 of Set 11 | ketchikan
# Processing Record 19 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 11 | la ronge
# Processing Record 21 of Set 11 | grand-santi
# Processing Record 22 of Set 11 | itacoatiara
# Processing Record 23 of Set 11 | pisco
# Processing Record 24 of Set 11 | easton
# Processing Record 25 of Set 11 | rudnichnyy
# Processing Record 26 of Set 11 | manokwari
# Processing Record 27 of Set 11 | somerset
# Processing Record 28 of Set 11 | oxapampa
# Processing Record 29 of Set 11 | pangnirtung
# Processing Record 30 of Set 11 | barcelos
# Processing Record 31 of Set 11 | labuan
# Processing Record 32 of Set 11 | loubomo
# Processing Record 33 of Set 11 | jacqueville
# Processing Record 34 of Set 11 | neftcala
# Processing Record 35 of Set 11 | padong
# Processing Record 36 of Set 11 | karatsu
# Processing Record 37 of Set 11 | coldwater
# Processing Record 38 of Set 11 | concepcion
# Processing Record 39 of Set 11 | ewa beach
# Processing Record 40 of Set 11 | grafton
# Processing Record 41 of Set 11 | ocampo
# Processing Record 42 of Set 11 | weston
# Processing Record 43 of Set 11 | tete
# Processing Record 44 of Set 11 | aklavik
# Processing Record 45 of Set 11 | nampula
# Processing Record 46 of Set 11 | tura
# Processing Record 47 of Set 11 | balkhash
# Processing Record 48 of Set 11 | zapolyarnyy
# Processing Record 49 of Set 11 | terney
# Processing Record 50 of Set 11 | adeje
# Processing Record 1 of Set 12 | kumano
# Processing Record 2 of Set 12 | axim
# Processing Record 3 of Set 12 | algiers
# Processing Record 4 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 12 | bambanglipuro
# Processing Record 6 of Set 12 | lerwick
# Processing Record 7 of Set 12 | mattru
# Processing Record 8 of Set 12 | shubarshi
# Processing Record 9 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 10 of Set 12 | sopot
# Processing Record 11 of Set 12 | ferreira do alentejo
# Processing Record 12 of Set 12 | marilia
# Processing Record 13 of Set 12 | magistralnyy
# Processing Record 14 of Set 12 | craig
# Processing Record 15 of Set 12 | golspie
# Processing Record 16 of Set 12 | kendal
# Processing Record 17 of Set 12 | saint-joseph
# Processing Record 18 of Set 12 | ergani
# Processing Record 19 of Set 12 | gold coast
# Processing Record 20 of Set 12 | rawlins
# Processing Record 21 of Set 12 | troy
# Processing Record 22 of Set 12 | elko
# Processing Record 23 of Set 12 | husavik
# Processing Record 24 of Set 12 | guarapari
# Processing Record 25 of Set 12 | waddan
# Processing Record 26 of Set 12 | villa rica
# Processing Record 27 of Set 12 | storforshei
# Processing Record 28 of Set 12 | tangzhai
# Processing Record 29 of Set 12 | upata
# Processing Record 30 of Set 12 | gamba
# Processing Record 31 of Set 12 | potanino
# Processing Record 32 of Set 12 | gazanjyk
# Processing Record 33 of Set 12 | camana
# Processing Record 34 of Set 12 | male
# Processing Record 35 of Set 12 | constantine
# Processing Record 36 of Set 12 | viedma
# Processing Record 37 of Set 12 | jardim
# Processing Record 38 of Set 12 | gawan
# Processing Record 39 of Set 12 | sangin
# Processing Record 40 of Set 12 | puerto escondido
# Processing Record 41 of Set 12 | tukrah
# Processing Record 42 of Set 12 | zabid
# Processing Record 43 of Set 12 | skibbereen
# Processing Record 44 of Set 12 | george town
# Processing Record 45 of Set 12 | kostomuksha
# Processing Record 46 of Set 12 | tromso
# Processing Record 47 of Set 12 | labuhan
# Processing Record 48 of Set 12 | ambovombe
# Processing Record 49 of Set 12 | panzhihua
# Processing Record 50 of Set 12 | mormugao
# Processing Record 1 of Set 13 | ponta delgada
# Processing Record 2 of Set 13 | rapid valley
# Processing Record 3 of Set 13 | coro
# Processing Record 4 of Set 13 | ust-tsilma
# Processing Record 5 of Set 13 | puerto del rosario
# Processing Record 6 of Set 13 | rafaela
# Processing Record 7 of Set 13 | shingu
# Processing Record 8 of Set 13 | norrtalje
# Processing Record 9 of Set 13 | teguldet
# Processing Record 10 of Set 13 | constitucion
# Processing Record 11 of Set 13 | llangefni
# Processing Record 12 of Set 13 | preobrazheniye
# Processing Record 13 of Set 13 | juegang
# Processing Record 14 of Set 13 | fairbanks
# Processing Record 15 of Set 13 | kirkenaer
# Processing Record 16 of Set 13 | sarande
# Processing Record 17 of Set 13 | yeniseysk
# Processing Record 18 of Set 13 | kiama
# Processing Record 19 of Set 13 | ostrovnoy
# Processing Record 20 of Set 13 | the valley
# Processing Record 21 of Set 13 | bollnas
# Processing Record 22 of Set 13 | longyearbyen
# Processing Record 23 of Set 13 | saint-augustin
# Processing Record 24 of Set 13 | chakulia
# Processing Record 25 of Set 13 | boende
# Processing Record 26 of Set 13 | coldstream
# Processing Record 27 of Set 13 | sarahan
# Processing Record 28 of Set 13 | gat
# Processing Record 29 of Set 13 | okhotsk
# Processing Record 30 of Set 13 | barabai
# Processing Record 31 of Set 13 | halifax
# Processing Record 32 of Set 13 | port augusta
# Processing Record 33 of Set 13 | pimentel
# Processing Record 34 of Set 13 | mizdah
# Processing Record 35 of Set 13 | piacabucu
# Processing Record 36 of Set 13 | ambilobe
# Processing Record 37 of Set 13 | ciro marina
# Processing Record 38 of Set 13 | sivaki
# Processing Record 39 of Set 13 | moose factory
# Processing Record 40 of Set 13 | mangai
# Processing Record 41 of Set 13 | betanzos
# Processing Record 42 of Set 13 | zhangjiakou
# Processing Record 43 of Set 13 | sarkand
# Processing Record 44 of Set 13 | esso
# Processing Record 45 of Set 13 | brigantine
# Processing Record 46 of Set 13 | chara
# Processing Record 47 of Set 13 | chilca
# Processing Record 48 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 13 | lagoa
# Processing Record 50 of Set 13 | sassandra
# Processing Record 1 of Set 14 | faya
# Processing Record 2 of Set 14 | yashkul
# Processing Record 3 of Set 14 | kismayo
# Processing Record 4 of Set 14 | saint george
# Processing Record 5 of Set 14 | avera
# Processing Record 6 of Set 14 | gweta
# Processing Record 7 of Set 14 | bantry
# Processing Record 8 of Set 14 | palasa
# Processing Record 9 of Set 14 | nelson bay
# Processing Record 10 of Set 14 | nagai
# Processing Record 11 of Set 14 | devils lake
# Processing Record 12 of Set 14 | tonj
# Processing Record 13 of Set 14 | mersing
# Processing Record 14 of Set 14 | opuwo
# Processing Record 15 of Set 14 | mitchell
# Processing Record 16 of Set 14 | haimen
# Processing Record 17 of Set 14 | gandzak
# Processing Record 18 of Set 14 | waslala
# Processing Record 19 of Set 14 | manuk mangkaw
# Processing Record 20 of Set 14 | pemba
# Processing Record 21 of Set 14 | gien
# Processing Record 22 of Set 14 | shimanovsk
# Processing Record 23 of Set 14 | luganville
# Processing Record 24 of Set 14 | santiago del estero
# Processing Record 25 of Set 14 | bose
# Processing Record 26 of Set 14 | yago
# Processing Record 27 of Set 14 | terrace
# Processing Record 28 of Set 14 | camacha
# Processing Record 29 of Set 14 | thouars
# Processing Record 30 of Set 14 | ligayan
# Processing Record 31 of Set 14 | coquimbo
# Processing Record 32 of Set 14 | pilar
# Processing Record 33 of Set 14 | eidsvag
# Processing Record 34 of Set 14 | copiapo
# Processing Record 35 of Set 14 | morros
# Processing Record 36 of Set 14 | chapais
# Processing Record 37 of Set 14 | bella vista
# Processing Record 38 of Set 14 | kalispell
# Processing Record 39 of Set 14 | atlantic city
# Processing Record 40 of Set 14 | billings
# Processing Record 41 of Set 14 | mamlyutka
# Processing Record 42 of Set 14 | soc trang
# Processing Record 43 of Set 14 | boa vista
# Processing Record 44 of Set 14 | okato
# Processing Record 45 of Set 14 | santa pola
# Processing Record 46 of Set 14 | khartoum
# Processing Record 47 of Set 14 | calama
# Processing Record 48 of Set 14 | bosaso
# Processing Record 49 of Set 14 | san blas
# Processing Record 50 of Set 14 | tautira
# Processing Record 1 of Set 15 | flinders
# Processing Record 2 of Set 15 | minab
# Processing Record 3 of Set 15 | yangshe
# Processing Record 4 of Set 15 | maceio
# Processing Record 5 of Set 15 | mount darwin
# Processing Record 6 of Set 15 | kropotkin
# Processing Record 7 of Set 15 | kloulklubed
# Processing Record 8 of Set 15 | mahad
# Processing Record 9 of Set 15 | kununurra
# Processing Record 10 of Set 15 | pauini
# Processing Record 11 of Set 15 | egvekinot
# Processing Record 12 of Set 15 | vao
# Processing Record 13 of Set 15 | katherine
# Processing Record 14 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 15 of Set 15 | shenjiamen
# Processing Record 16 of Set 15 | kupang
# Processing Record 17 of Set 15 | yar-sale
# Processing Record 18 of Set 15 | pedro ii
# Processing Record 19 of Set 15 | liuhe
# Processing Record 20 of Set 15 | bull savanna
# Processing Record 21 of Set 15 | talakan
# Processing Record 22 of Set 15 | arman
# Processing Record 23 of Set 15 | tiarei
# Processing Record 24 of Set 15 | bima
# Processing Record 25 of Set 15 | buenos aires
# Processing Record 26 of Set 15 | road town
# Processing Record 27 of Set 15 | caxito
# Processing Record 28 of Set 15 | itarema
# Processing Record 29 of Set 15 | verkhnyaya inta
# Processing Record 30 of Set 15 | inhambane
# Processing Record 31 of Set 15 | hai duong
# Processing Record 32 of Set 15 | pegnitz
# Processing Record 33 of Set 15 | cavalcante
# Processing Record 34 of Set 15 | aripuana
# Processing Record 35 of Set 15 | sobolevo
# Processing Record 36 of Set 15 | iskateley
# Processing Record 37 of Set 15 | cassilandia
# Processing Record 38 of Set 15 | beidao
# Processing Record 39 of Set 15 | san luis
# Processing Record 40 of Set 15 | khandbari
# Processing Record 41 of Set 15 | fare
# Processing Record 42 of Set 15 | linfen
# Processing Record 43 of Set 15 | san cristobal
# Processing Record 44 of Set 15 | tarhunah
# City not found. Skipping...
# Processing Record 45 of Set 15 | richards bay
# Processing Record 46 of Set 15 | honningsvag
# Processing Record 47 of Set 15 | nivala
# Processing Record 48 of Set 15 | cahabon
# Processing Record 49 of Set 15 | taonan
# Processing Record 50 of Set 15 | caborca
# Processing Record 1 of Set 16 | magadi
# Processing Record 2 of Set 16 | atar
# Processing Record 3 of Set 16 | boquira
# Processing Record 4 of Set 16 | canaries
# Processing Record 5 of Set 16 | machali
# Processing Record 6 of Set 16 | kamphaeng phet
# Processing Record 7 of Set 16 | mabilo
# City not found. Skipping...
# Processing Record 8 of Set 16 | bela
# Processing Record 9 of Set 16 | ijaki
# City not found. Skipping...
# Processing Record 10 of Set 16 | praia da vitoria
# Processing Record 11 of Set 16 | camacupa
# Processing Record 12 of Set 16 | cam ranh
# Processing Record 13 of Set 16 | awbari
# Processing Record 14 of Set 16 | wajima
# Processing Record 15 of Set 16 | negara
# Processing Record 16 of Set 16 | yafran
# Processing Record 17 of Set 16 | menongue
# Processing Record 18 of Set 16 | nantucket
# Processing Record 19 of Set 16 | kaeo
# Processing Record 20 of Set 16 | vanimo
# Processing Record 21 of Set 16 | kortkeros
# Processing Record 22 of Set 16 | casablanca
# Processing Record 23 of Set 16 | rio branco
# Processing Record 24 of Set 16 | bemmel
# Processing Record 25 of Set 16 | mandalgovi
# Processing Record 26 of Set 16 | abnub
# Processing Record 27 of Set 16 | noumea
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 719

# %% [markdown]
# ### Add the data to a new DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Bluff -46.6000  168.3333     41.00        95          28
# 1   Alice Springs -23.7000  133.8833     60.80        63           6
# 2           Kapaa  22.0752 -159.3190     75.20        53           1
# 3     Sakaiminato  35.5500  133.2333     50.00        71          20
# 4        Iracoubo   5.4802  -53.2011     78.30        87         100
# 5  Guerrero Negro  27.9769 -114.0611     74.52        49          19
# 6    Hagere Selam   6.4833   38.5167     51.80        78          94
# 7      Butaritari   3.0707  172.7902     81.46        80          64
# 8      Walvis Bay -22.9575   14.5053     77.00        38           0
# 9         Mataura -46.1927  168.8643     41.00        95           8
#
#    Wind Speed Country                 Date Current Description
# 0        6.82      NZ  2021-04-08 18:08:01    scattered clouds
# 1        4.61      AU  2021-04-08 18:04:08           clear sky
# 2       17.27      US  2021-04-08 18:08:02           clear sky
# 3        8.05      JP  2021-04-08 18:08:02          few clouds
# 4        5.73      GF  2021-04-08 18:08:03     overcast clouds
# 5       16.28      MX  2021-04-08 18:04:53          few clouds
# 6        6.51      ET  2021-04-08 18:08:03     overcast clouds
# 7       17.25      KI  2021-04-08 18:08:04       broken clouds
# 8        8.05      NA  2021-04-08 18:08:04           clear sky
# 9        2.26      NZ  2021-04-08 18:08:05           clear sky

# %% [markdown]
# ### Adjust the column order

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Bluff      NZ -46.6000  168.3333     41.00        95          28
# 1   Alice Springs      AU -23.7000  133.8833     60.80        63           6
# 2           Kapaa      US  22.0752 -159.3190     75.20        53           1
# 3     Sakaiminato      JP  35.5500  133.2333     50.00        71          20
# 4        Iracoubo      GF   5.4802  -53.2011     78.30        87         100
# 5  Guerrero Negro      MX  27.9769 -114.0611     74.52        49          19
# 6    Hagere Selam      ET   6.4833   38.5167     51.80        78          94
# 7      Butaritari      KI   3.0707  172.7902     81.46        80          64
# 8      Walvis Bay      NA -22.9575   14.5053     77.00        38           0
# 9         Mataura      NZ -46.1927  168.8643     41.00        95           8
#
#    Wind Speed Current Description
# 0        6.82    scattered clouds
# 1        4.61           clear sky
# 2       17.27           clear sky
# 3        8.05          few clouds
# 4        5.73     overcast clouds
# 5       16.28          few clouds
# 6        6.51     overcast clouds
# 7       17.25       broken clouds
# 8        8.05           clear sky
# 9        2.26           clear sky

# %% [markdown]
# ### Export the DataFrame as a CSV file

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
